# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
from scipy.stats import pointbiserialr

# %%
import os

ruta = os.path.join(os.getcwd(), "..", "..", "data", "processed", "peleas_ponderadas.parquet")
df = pd.read_parquet(ruta)
df.head()
# Out:
#         DATE       Peleador_A       Peleador_B  WINNER  KD_A  KD_B  SIG_STR_A  \
# 0 2000-06-09  Kevin Randleman      Pedro Rizzo   False  0.00  0.60     0.2956
# 1 2000-09-22      Jeremy Horn   Eugene Jackson   False  0.00  0.64     0.6996
# 2 2001-02-23       Tito Ortiz      Evan Tanner   False  0.24  0.00     0.4776
# 3 2001-05-04    Chuck Liddell  Kevin Randleman   False  0.00  0.00     0.5048
# 4 2001-06-29     Pat Miletich    Shonie Carter   False  0.00  0.72     0.4664
#
#    SIG_STR_B  TD_PORC_A  TD_PORC_B  ...   Puntos_A   Puntos_B  Peleas_A  \
# 0     0.3724     0.8344     0.0000  ...   1.927756   5.921462         3
# 1     0.5160     0.1680     0.0000  ...  10.209519   0.000000         3
# 2     0.7144     0.8704     1.0000  ...   7.495669   6.203725         5
# 3     0.4496     0.0000     0.6960  ...   4.775221   0.000000         3
# 4     0.5272     0.6400     0.6896  ...   0.000000  10.170940         5
#
#    Peleas_B  KD_DIFF  SIG_STR_DIFF   TD_DIFF  SUB_ATT_DIFF  REV_DIFF  \
# 0         3    -0.60       -0.0768  0.650000          0.72      0.00
# 1         3    -0.64        0.1836  0.315789          0.80      0.00
# 2         3     0.24       -0.2368  0.221893         -1.12      0.00
# 3         5     0.00        0.0552 -0.508475         -1.64      0.40
# 4         3    -0.72       -0.0608  0.022094          0.88     -1.12
#
#    CTRL_DIFF
# 0     378.72
# 1      -2.24
# 2     600.96
# 3    -601.12
# 4    -122.28
#
# [5 rows x 78 columns]

# %%
print("Columnas del DataFrame:")
print(df.columns)
# Out:
# Columnas del DataFrame:
# Index(['DATE', 'Peleador_A', 'Peleador_B', 'WINNER', 'KD_A', 'KD_B',
#        'SIG_STR_A', 'SIG_STR_B', 'TD_PORC_A', 'TD_PORC_B', 'SUB_ATT_A',
#        'SUB_ATT_B', 'REV_A', 'REV_B', 'CTRL_A', 'CTRL_B', 'TOTAL_STR_A_x',
#        'TOTAL_STR_B_x', 'TOTAL_STR_A_y', 'TOTAL_STR_B_y', 'TD_A_x', 'TD_B_x',
#        'TD_A_y', 'TD_B_y', 'STR_HEAD_A_x', 'STR_HEAD_B_x', 'STR_HEAD_A_y',
#        'STR_HEAD_B_y', 'STR_BODY_A_x', 'STR_BODY_B_x', 'STR_BODY_A_y',
#        'STR_BODY_B_y', 'STR_LEG_A_x', 'STR_LEG_B_x', 'STR_LEG_A_y',
#        'STR_LEG_B_y', 'STR_DISTANCE_A_x', 'STR_DISTANCE_B_x',
#        'STR_DISTANCE_A_y', 'STR_DISTANCE_B_y', 'STR_CLINCH_A_x',
#        'STR_CLINCH_B_x', 'STR_CLINCH_A_y', 'STR_CLINCH_B_y', 'STR_GROUND_A_x',
#        'STR_GROUND_B_x', 'STR_GROUND_A_y', 'STR_GROUND_B_y', 'STRIKER_A',
#        'STRIKER_B', 'GRAPPLER_A', 'GRAPPLER_B', 'Victorias_KO_A',
#        'Victorias_KO_B', 'Victorias_Sub_A', 'Victorias_Sub_B',
#        'Victorias_Decision_A', 'Victorias_Decision_B', 'Derrotas_KO_A',
#        'Derrotas_KO_B', 'Derrotas_Sub_A', 'Derrotas_Sub_B',
#        'Derrotas_Decision_A', 'Derrotas_Decision_B', 'Record_A', 'Record_B',
#        'Racha_A', 'Racha_B', 'Puntos_A', 'Puntos_B', 'Peleas_A', 'Peleas_B',
#        'KD_DIFF', 'SIG_STR_DIFF', 'TD_DIFF', 'SUB_ATT_DIFF', 'REV_DIFF',
#        'CTRL_DIFF'],
#       dtype='object')

# %%
print("\nTipos de datos:")
print(df.dtypes.to_string())
# Out:
# Tipos de datos:
# DATE                    datetime64[ns]
# Peleador_A                      object
# Peleador_B                      object
# WINNER                            bool
# KD_A                           float64
# KD_B                           float64
# SIG_STR_A                      float64
# SIG_STR_B                      float64
# TD_PORC_A                      float64
# TD_PORC_B                      float64
# SUB_ATT_A                      float64
# SUB_ATT_B                      float64
# REV_A                          float64
# REV_B                          float64
# CTRL_A                         float64
# CTRL_B                         float64
# TOTAL_STR_A_x                  float64
# TOTAL_STR_B_x                  float64
# TOTAL_STR_A_y                  float64
# TOTAL_STR_B_y                  float64
# TD_A_x                         float64
# TD_B_x                         float64
# TD_A_y                         float64
# TD_B_y                         float64
# STR_HEAD_A_x                   float64
# STR_HEAD_B_x                   float64
# STR_HEAD_A_y                   float64
# STR_HEAD_B_y                   float64
# STR_BODY_A_x                   float64
# STR_BODY_B_x                   float64
# STR_BODY_A_y                   float64
# STR_BODY_B_y                   float64
# STR_LEG_A_x                    float64
# STR_LEG_B_x                    float64
# STR_LEG_A_y                    float64
# STR_LEG_B_y                    float64
# STR_DISTANCE_A_x               float64
# STR_DISTANCE_B_x               float64
# STR_DISTANCE_A_y               float64
# STR_DISTANCE_B_y               float64
# STR_CLINCH_A_x                 float64
# STR_CLINCH_B_x                 float64
# STR_CLINCH_A_y                 float64
# STR_CLINCH_B_y                 float64
# STR_GROUND_A_x                 float64
# STR_GROUND_B_x                 float64
# STR_GROUND_A_y                 float64
# STR_GROUND_B_y                 float64
# STRIKER_A                      float64
# STRIKER_B                      float64
# GRAPPLER_A                     float64
# GRAPPLER_B                     float64
# Victorias_KO_A                 float64
# Victorias_KO_B                 float64
# Victorias_Sub_A                float64
# Victorias_Sub_B                float64
# Victorias_Decision_A           float64
# Victorias_Decision_B           float64
# Derrotas_KO_A                  float64
# Derrotas_KO_B                  float64
# Derrotas_Sub_A                 float64
# Derrotas_Sub_B                 float64
# Derrotas_Decision_A            float64
# Derrotas_Decision_B            float64
# Record_A                       float64
# Record_B                       float64
# Racha_A                          int64
# Racha_B                          int64
# Puntos_A                       float64
# Puntos_B                       float64
# Peleas_A                         int64
# Peleas_B                         int64
# KD_DIFF                        float64
# SIG_STR_DIFF                   float64
# TD_DIFF                        float64
# SUB_ATT_DIFF                   float64
# REV_DIFF                       float64
# CTRL_DIFF                      float64

# %% [markdown]
# ## ANALÍSIS DESCRIPTIVO NÚMERICO

# %% [markdown]
# Realizamos un análisis descriptivo de las variables numéricas para comprender mejor sus distribuciones
# y las frecuencias con las que ocurren ciertos eventos en las peleas. Por ejemplo, observamos que el número
# de knockdowns (KD) suele ser 0 en la mayoría de los combates, mientras que el número total de golpes conectados
# (TOTAL_STR_A_x) suele superar los 55.
#
# Este análisis también nos permite verificar si la extracción y transformación de los datos se ha realizado
# correctamente. De hecho, detectamos que algunos porcentajes estaban guardándose en una escala de 0 a 100 en
# lugar de 0 a 1, lo que pudimos corregir gracias a esta exploración descriptiva.

# %%
print("\nResumen estadístico de columnas numéricas:")
pd.set_option('display.max_columns', None)
print(df.describe(include='all'))
# Out:
# Resumen estadístico de columnas numéricas:
#                                  DATE       Peleador_A       Peleador_B  \
# count                            3520             3520             3520
# unique                            NaN              905             1121
# top                               NaN  Andrei Arlovski  Jeremy Stephens
# freq                              NaN               23               18
# mean    2017-12-29 23:15:49.090909184              NaN              NaN
# min               2000-06-09 00:00:00              NaN              NaN
# 25%               2014-09-05 00:00:00              NaN              NaN
# 50%               2018-08-04 00:00:00              NaN              NaN
# 75%               2022-04-09 00:00:00              NaN              NaN
# max               2025-04-12 00:00:00              NaN              NaN
# std                               NaN              NaN              NaN
#
#        WINNER         KD_A         KD_B    SIG_STR_A    SIG_STR_B  \
# count    3520  3520.000000  3520.000000  3520.000000  3520.000000
# unique      2          NaN          NaN          NaN          NaN
# top     False          NaN          NaN          NaN          NaN
# freq     2095          NaN          NaN          NaN          NaN
# mean      NaN     0.269818     0.279864     0.466794     0.470505
# min       NaN     0.000000     0.000000     0.079200     0.132000
# 25%       NaN     0.000000     0.000000     0.397200     0.402300
# 50%       NaN     0.240000     0.240000     0.464800     0.468600
# 75%       NaN     0.400000     0.400000     0.532500     0.534400
# max       NaN     2.200000     2.640000     0.888000     0.865600
# std       NaN     0.348787     0.348894     0.105571     0.100966
#
#           TD_PORC_A    TD_PORC_B    SUB_ATT_A   SUB_ATT_B        REV_A  \
# count   3520.000000  3520.000000  3520.000000  3520.00000  3520.000000
# unique          NaN          NaN          NaN         NaN          NaN
# top             NaN          NaN          NaN         NaN          NaN
# freq            NaN          NaN          NaN         NaN          NaN
# mean       0.277350     0.279073     0.381659     0.41058     0.118045
# min        0.000000     0.000000     0.000000     0.00000     0.000000
# 25%        0.079200     0.079200     0.000000     0.00000     0.000000
# 50%        0.243400     0.240000     0.240000     0.24000     0.000000
# 75%        0.420000     0.433600     0.600000     0.64000     0.240000
# max        1.000000     1.000000     3.600000     4.20000     2.360000
# std        0.226043     0.228846     0.531314     0.55503     0.245325
#
#               REV_B       CTRL_A       CTRL_B  TOTAL_STR_A_x  TOTAL_STR_B_x  \
# count   3520.000000  3520.000000  3520.000000    3520.000000    3520.000000
# unique          NaN          NaN          NaN            NaN            NaN
# top             NaN          NaN          NaN            NaN            NaN
# freq            NaN          NaN          NaN            NaN            NaN
# mean       0.131841   146.361375   140.974716      62.161580      59.757534
# min        0.000000     0.000000     0.000000       0.720000       1.840000
# 25%        0.000000    41.980000    45.470000      38.430000      36.800000
# 50%        0.000000   109.360000   107.640000      56.200000      55.240000
# 75%        0.240000   215.390000   203.620000      79.610000      77.610000
# max        2.760000   993.600000   859.040000     297.000000     242.040000
# std        0.258129   134.024261   124.668997      33.894588      31.522595
#
#         TOTAL_STR_A_y  TOTAL_STR_B_y       TD_A_x       TD_B_x       TD_A_y  \
# count     3520.000000    3520.000000  3520.000000  3520.000000  3520.000000
# unique            NaN            NaN          NaN          NaN          NaN
# top               NaN            NaN          NaN          NaN          NaN
# freq              NaN            NaN          NaN          NaN          NaN
# mean       116.909091     111.231898     1.176273     1.132273     3.026205
# min          3.640000       4.120000     0.000000     0.000000     0.000000
# 25%         74.080000      69.400000     0.240000     0.240000     0.760000
# 50%        107.280000     104.900000     0.760000     0.760000     2.200000
# 75%        150.010000     144.080000     1.800000     1.600000     4.490000
# max        523.160000     446.080000     8.640000     9.560000    27.640000
# std         61.061878      56.611012     1.256942     1.259720     2.916684
#
#              TD_B_y  STR_HEAD_A_x  STR_HEAD_B_x  STR_HEAD_A_y  STR_HEAD_B_y  \
# count   3520.000000   3520.000000   3520.000000   3520.000000   3520.000000
# unique          NaN           NaN           NaN           NaN           NaN
# top             NaN           NaN           NaN           NaN           NaN
# freq            NaN           NaN           NaN           NaN           NaN
# mean       2.868830     27.399091     26.253716     74.068693     70.017932
# min        0.000000      0.000000      0.240000      2.320000      1.080000
# 25%        0.760000     15.280000     14.760000     41.720000     39.340000
# 50%        2.040000     23.680000     22.760000     65.220000     62.820000
# 75%        4.200000     35.240000     34.040000     95.810000     92.130000
# max       22.120000    170.680000    137.600000    384.640000    332.800000
# std        2.791585     17.543527     16.265256     45.203318     41.457066
#
#         STR_BODY_A_x  STR_BODY_B_x  STR_BODY_A_y  STR_BODY_B_y  STR_LEG_A_x  \
# count    3520.000000   3520.000000   3520.000000   3520.000000  3520.000000
# unique           NaN           NaN           NaN           NaN          NaN
# top              NaN           NaN           NaN           NaN          NaN
# freq             NaN           NaN           NaN           NaN          NaN
# mean        8.758659      8.216716     12.583193     11.754341     7.050398
# min         0.000000      0.000000      0.000000      0.000000     0.000000
# 25%         3.920000      3.560000      5.680000      5.280000     2.400000
# 50%         7.080000      6.680000     10.440000      9.480000     5.160000
# 75%        11.800000     11.080000     17.000000     15.890000     9.680000
# max        77.760000     62.640000     94.360000     80.200000    63.360000
# std         6.929062      6.526805      9.560486      9.102917     6.693382
#
#         STR_LEG_B_x  STR_LEG_A_y  STR_LEG_B_y  STR_DISTANCE_A_x  \
# count   3520.000000  3520.000000  3520.000000       3520.000000
# unique          NaN          NaN          NaN               NaN
# top             NaN          NaN          NaN               NaN
# freq            NaN          NaN          NaN               NaN
# mean       6.388011     8.691034     7.859977         31.832523
# min        0.000000     0.000000     0.000000          0.000000
# 25%        2.080000     2.960000     2.600000         14.200000
# 50%        4.840000     6.380000     5.920000         26.160000
# 75%        8.760000    11.920000    10.760000         42.930000
# max       48.400000    82.280000    67.080000        259.720000
# std        5.966841     8.266324     7.348056         24.209320
#
#         STR_DISTANCE_B_x  STR_DISTANCE_A_y  STR_DISTANCE_B_y  STR_CLINCH_A_x  \
# count        3520.000000       3520.000000       3520.000000     3520.000000
# unique               NaN               NaN               NaN             NaN
# top                  NaN               NaN               NaN             NaN
# freq                 NaN               NaN               NaN             NaN
# mean           29.587784         79.164352         73.456625        5.371591
# min             0.000000          2.040000          1.320000        0.000000
# 25%            12.960000         39.120000         36.200000        1.840000
# 50%            24.900000         67.880000         63.240000        3.940000
# 75%            40.240000        107.360000        100.300000        7.240000
# max           210.680000        479.960000        405.000000       46.440000
# std            21.913422         54.883504         49.717337        5.143465
#
#         STR_CLINCH_B_x  STR_CLINCH_A_y  STR_CLINCH_B_y  STR_GROUND_A_x  \
# count      3520.000000      3520.00000     3520.000000     3520.000000
# unique             NaN             NaN             NaN             NaN
# top                NaN             NaN             NaN             NaN
# freq               NaN             NaN             NaN             NaN
# mean          5.508716         7.62833        7.831125        6.004034
# min           0.000000         0.00000        0.000000        0.000000
# 25%           1.880000         2.88000        2.840000        1.440000
# 50%           4.000000         5.74000        5.840000        3.920000
# 75%           7.600000        10.20000       10.680000        8.040000
# max          44.720000        64.36000       66.840000       69.320000
# std           5.199586         6.91323        7.055716        6.830235
#
#         STR_GROUND_B_x  STR_GROUND_A_y  STR_GROUND_B_y    STRIKER_A  \
# count      3520.000000     3520.000000     3520.000000  3520.000000
# unique             NaN             NaN             NaN          NaN
# top                NaN             NaN             NaN          NaN
# freq               NaN             NaN             NaN          NaN
# mean          5.761943        8.550239        8.344500    51.264665
# min           0.000000        0.000000        0.000000     1.688571
# 25%           1.520000        2.000000        2.240000    21.100994
# 50%           3.960000        5.520000        5.660000    36.484048
# 75%           8.040000       11.680000       11.600000    67.202857
# max          51.400000       94.480000       62.800000   393.520000
# std           6.020207        9.569926        8.702354    44.275714
#
#           STRIKER_B   GRAPPLER_A   GRAPPLER_B  Victorias_KO_A  Victorias_KO_B  \
# count   3520.000000  3520.000000  3520.000000     3520.000000     3520.000000
# unique          NaN          NaN          NaN             NaN             NaN
# top             NaN          NaN          NaN             NaN             NaN
# freq            NaN          NaN          NaN             NaN             NaN
# mean      49.910890     0.034182     0.035399        2.217000        1.688045
# min        2.075000     0.000000     0.000000        0.000000        0.000000
# 25%       20.093333     0.007153     0.006791        0.600000        0.000000
# 50%       37.082333     0.021083     0.020815        1.600000        1.000000
# 75%       65.475000     0.044698     0.044604        3.360000        2.360000
# max      377.840000     1.003978     0.961005       13.600000       13.360000
# std       41.613922     0.048380     0.051309        2.212246        1.900822
#
#         Victorias_Sub_A  Victorias_Sub_B  Victorias_Decision_A  \
# count       3520.000000      3520.000000           3520.000000
# unique              NaN              NaN                   NaN
# top                 NaN              NaN                   NaN
# freq                NaN              NaN                   NaN
# mean           1.245386         0.968659              2.720966
# min            0.000000         0.000000              0.000000
# 25%            0.000000         0.000000              1.000000
# 50%            1.000000         0.360000              2.000000
# 75%            2.000000         1.360000              4.000000
# max           16.000000        13.360000             14.000000
# std            1.730433         1.421628              2.386842
#
#         Victorias_Decision_B  Derrotas_KO_A  Derrotas_KO_B  Derrotas_Sub_A  \
# count            3520.000000    3520.000000    3520.000000     3520.000000
# unique                   NaN            NaN            NaN             NaN
# top                      NaN            NaN            NaN             NaN
# freq                     NaN            NaN            NaN             NaN
# mean                2.041227       0.883477       0.691750        0.574375
# min                 0.000000       0.000000       0.000000        0.000000
# 25%                 0.600000       0.000000       0.000000        0.000000
# 50%                 1.600000       0.600000       0.000000        0.000000
# 75%                 3.000000       1.000000       1.000000        1.000000
# max                13.000000       7.600000       7.360000        7.000000
# std                 1.996071       1.160996       0.961893        0.968069
#
#         Derrotas_Sub_B  Derrotas_Decision_A  Derrotas_Decision_B     Record_A  \
# count      3520.000000          3520.000000          3520.000000  3520.000000
# unique             NaN                  NaN                  NaN          NaN
# top                NaN                  NaN                  NaN          NaN
# freq               NaN                  NaN                  NaN          NaN
# mean          0.476648             1.533398             1.299773    11.961648
# min           0.000000             0.000000             0.000000    -1.000000
# 25%           0.000000             0.000000             0.000000     8.000000
# 50%           0.000000             1.000000             1.000000    11.000000
# 75%           1.000000             2.000000             2.000000    16.000000
# max           6.000000            11.360000            11.000000    71.000000
# std           0.822771             1.663858             1.472219     6.566767
#
#            Record_B      Racha_A      Racha_B     Puntos_A     Puntos_B  \
# count   3520.000000  3520.000000  3520.000000  3520.000000  3520.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean      11.223864     1.509375     1.547727    63.669156    51.302593
# min       -2.000000     0.000000     0.000000     0.000000     0.000000
# 25%        8.000000     0.000000     0.000000    10.000000     9.445585
# 50%       11.000000     1.000000     1.000000    28.949490    23.328169
# 75%       14.000000     2.000000     3.000000    80.037926    68.411190
# max       72.000000    19.000000    13.000000  1602.815131   732.646566
# std        6.553810     2.204370     1.745695   100.217655    73.411044
#
#            Peleas_A     Peleas_B      KD_DIFF  SIG_STR_DIFF      TD_DIFF  \
# count   3520.000000  3520.000000  3520.000000   3520.000000  3520.000000
# unique          NaN          NaN          NaN           NaN          NaN
# top             NaN          NaN          NaN           NaN          NaN
# freq            NaN          NaN          NaN           NaN          NaN
# mean      10.305398     8.307955    -0.010045     -0.003711     0.001883
# min        3.000000     3.000000    -2.600000     -0.527200    -0.720721
# 25%        6.000000     4.000000    -0.280000     -0.097300    -0.173103
# 50%        9.000000     7.000000     0.000000     -0.004800     0.000000
# 75%       13.000000    11.000000     0.240000      0.088500     0.167737
# max       44.000000    43.000000     2.200000      0.557600     0.741667
# std        6.255766     5.304541     0.469689      0.138366     0.241120
#
#         SUB_ATT_DIFF     REV_DIFF    CTRL_DIFF
# count     3520.00000  3520.000000  3520.000000
# unique           NaN          NaN          NaN
# top              NaN          NaN          NaN
# freq             NaN          NaN          NaN
# mean        -0.02892    -0.013795     5.386659
# min         -3.60000    -2.360000  -731.160000
# 25%         -0.40000     0.000000   -93.580000
# 50%          0.00000     0.000000    -1.800000
# 75%          0.36000     0.000000    95.140000
# max          3.60000     2.360000   692.160000
# std          0.72547     0.348119   172.528609

# %%
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns
print(numerical_columns)
# Out:
# Index(['KD_A', 'KD_B', 'SIG_STR_A', 'SIG_STR_B', 'TD_PORC_A', 'TD_PORC_B',
#        'SUB_ATT_A', 'SUB_ATT_B', 'REV_A', 'REV_B', 'CTRL_A', 'CTRL_B',
#        'TOTAL_STR_A_x', 'TOTAL_STR_B_x', 'TOTAL_STR_A_y', 'TOTAL_STR_B_y',
#        'TD_A_x', 'TD_B_x', 'TD_A_y', 'TD_B_y', 'STR_HEAD_A_x', 'STR_HEAD_B_x',
#        'STR_HEAD_A_y', 'STR_HEAD_B_y', 'STR_BODY_A_x', 'STR_BODY_B_x',
#        'STR_BODY_A_y', 'STR_BODY_B_y', 'STR_LEG_A_x', 'STR_LEG_B_x',
#        'STR_LEG_A_y', 'STR_LEG_B_y', 'STR_DISTANCE_A_x', 'STR_DISTANCE_B_x',
#        'STR_DISTANCE_A_y', 'STR_DISTANCE_B_y', 'STR_CLINCH_A_x',
#        'STR_CLINCH_B_x', 'STR_CLINCH_A_y', 'STR_CLINCH_B_y', 'STR_GROUND_A_x',
#        'STR_GROUND_B_x', 'STR_GROUND_A_y', 'STR_GROUND_B_y', 'STRIKER_A',
#        'STRIKER_B', 'GRAPPLER_A', 'GRAPPLER_B', 'Victorias_KO_A',
#        'Victorias_KO_B', 'Victorias_Sub_A', 'Victorias_Sub_B',
#        'Victorias_Decision_A', 'Victorias_Decision_B', 'Derrotas_KO_A',
#        'Derrotas_KO_B', 'Derrotas_Sub_A', 'Derrotas_Sub_B',
#        'Derrotas_Decision_A', 'Derrotas_Decision_B', 'Record_A', 'Record_B',
#        'Racha_A', 'Racha_B', 'Puntos_A', 'Puntos_B', 'Peleas_A', 'Peleas_B',
#        'KD_DIFF', 'SIG_STR_DIFF', 'TD_DIFF', 'SUB_ATT_DIFF', 'REV_DIFF',
#        'CTRL_DIFF'],
#       dtype='object')

# %% [markdown]
# ## ANALÍSIS DISTRIBUCIONES CON BOX-PLOT

# %% [markdown]
# Al mostrar los Box-Plot nos damos cuenta de que en muchos casos
# existe una cola a la derecha ya que, por ejemplo en los intentos de derribo,
# lo normal es que ocurran muy pocos concentrandose ahí la mayoría de los valores,
# sin embargo en algunos combates ocurren mucho creando esa cola. Esto vemos que pasa con
# bastantes variables. Para mejorar eso deberíamos estudiar realizar ciertas transformaciones.
#
# También vemos gráficos en los cuales la distancia intercuartílica es mínima ya que, por ejemplo los knockdowns
# o intentos de sumisión suelen no ocurrir ni una vez en los combates, esto se puede ver en el dataframe explicando
# cada variable donde vemos que variables como los knockdowns (KD_A y KD_B) el 75% es 0 y tiene una media de 0.24,
# haciendo que se queden esos gráficos tan raros con la caja prácticamente siendo una línea. En cuanto a estas variables
# habrá que estudiar si aportan algo al crear el modelo al ser tan generales.

# %%
# Número de columnas
cols = 3

# Calcula el número de filas necesarias para los gráficos
rows = (len(numerical_columns) + cols - 1) // cols  # Redondeo hacia arriba

# Crear la figura
plt.figure(figsize=(5 * cols, 5 * rows))

# Crear los subgráficos
for i, col in enumerate(numerical_columns):
    plt.subplot(rows, cols, i + 1)  # Definir filas y columnas
    sns.boxplot(y=df[col])  # Usar 'y' para boxplot en vertical
    plt.title(f"Distribución de {col}")

# Ajustar la disposición para que no se sobrepongan
plt.tight_layout()

# Mostrar la figura
plt.show()

# %% [markdown]
# ## ANÁLISIS DISTRIBUCIONES CON HISTOGRAMAS

# %% [markdown]
# Como vemos en los histogramas las variables no siguen distribuciones normales
# y predomina, como ya habíamos visto con los boxplots las colas hacía la derecha. Intentaremos
# utilizar todos los datos ya que no parecen errores de la página y en caso de que sea un problema para el
# modelo eliminaremos algunos valores atípicos.

# %%
df.hist(figsize=(14, 10))
plt.suptitle("Histogramas de las variables", fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# ## Correlación con la variable objetivo

# %%
df_numericas = df.select_dtypes(include=["number"])

resultados = []

for col in df_numericas.columns:
    corr, p_value = pointbiserialr(df["WINNER"], df[col])
    resultados.append({"Variable": col, "Correlación": round(corr, 3), "P-valor": round(p_value, 5)})

# Convertir en DataFrame y ordenar por correlación absoluta
df_corr = pd.DataFrame(resultados).sort_values(by="Correlación", ascending=False)

# Mostrar tabla
df_corr
# Out:
#                Variable  Correlación  P-valor
# 58  Derrotas_Decision_A        0.112  0.00000
# 54        Derrotas_KO_A        0.105  0.00000
# 66             Peleas_A        0.103  0.00000
# 65             Puntos_B        0.084  0.00000
# 63              Racha_B        0.075  0.00001
# ..                  ...          ...      ...
# 73            CTRL_DIFF       -0.092  0.00000
# 40       STR_GROUND_A_x       -0.096  0.00000
# 10               CTRL_A       -0.096  0.00000
# 62              Racha_A       -0.098  0.00000
# 42       STR_GROUND_A_y       -0.109  0.00000
#
# [74 rows x 3 columns]

# %% [markdown]
# Al comparar las correlaciones antes y después de calcular la media ponderada de los combates pasados, observamos que algunas variables que inicialmente mostraban una fuerte relación con la variable objetivo "WINNER" han disminuido su correlación o incluso han desaparecido de la lista de variables significativamente relacionadas.
#
# Esto sugiere que, al promediar los datos de combates previos, se pierde parte de la información relevante para predecir el resultado de una pelea. Es posible que la variabilidad individual de cada combate, como el estado de forma actual del peleador o factores específicos de cada enfrentamiento, se diluya en el proceso de agregación.
#
# Como consecuencia, los modelos que utilicen este nuevo conjunto de datos basado en promedios ponderados podrían no ser tan precisos como aquellos que trabajan directamente con los datos reales de cada pelea. La reducción en la fuerza de las correlaciones indica que el modelo podría perder capacidad predictiva al no capturar ciertas dinámicas clave que estaban presentes en los datos originales

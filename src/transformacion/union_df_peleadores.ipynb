# %%
import pandas as pd

df_medias = pd.read_csv(r"C:\Users\andre\OneDrive - Universidad Complutense de Madrid (UCM)\Escritorio\UNIVERSIDAD\2º\2º Cuatrimestre\PD1\c2425-R4\data\medias_peleadores.csv")

df_peleadores = pd.read_csv(r"C:\Users\andre\OneDrive - Universidad Complutense de Madrid (UCM)\Escritorio\UNIVERSIDAD\2º\2º Cuatrimestre\PD1\c2425-R4\data\fighters_final_limpio.csv")


df_medias.columns.values[0] = "Nombre"
df_medias["Nombre"] = df_medias["Nombre"].str.upper()

set1 = set(df_medias["Nombre"])
set2 = set(df_peleadores["name"])

dif1 = set1 - set2
len(dif1)

dif2 = set2 - set1
len(dif2)
# Out:
# 529

# %%
pd.options.display.max_columns = None
df_medias[df_medias["Nombre"] == "ILIA TOPURIA"]
# Out:
#             Nombre  KD_A  SIG_STR_A  TD_PORC_A  SUB_ATT_A  REV_A   CTRL_A  \
# 1978  ILIA TOPURIA  0.75       0.48       0.35       0.75    0.0  133.375
#
#        KD_R  SIG_STR_R  TD_PORC_R  SUB_ATT_R  REV_R  CTRL_R    TD_T_A  \
# 1978  0.125     0.3825    0.01375      0.125  0.375    35.0  0.350694
#
#         TD_T_R    TD_M_A    TD_M_R  TOTAL_STR_T_A  TOTAL_STR_T_R  \
# 1978  0.013889  0.350694  0.013889       0.515615       0.442749
#
#       TOTAL_STR_M_A  TOTAL_STR_M_R  STR_HEAD_T_A  STR_HEAD_T_R  STR_HEAD_M_A  \
# 1978       0.515615       0.442749      0.409492      0.286625      0.409492
#
#       STR_HEAD_M_R  STR_BODY_T_A  STR_BODY_T_R  STR_BODY_M_A  STR_BODY_M_R  \
# 1978      0.286625      0.684461      0.536916      0.684461      0.536916
#
#       STR_LEG_T_A  STR_LEG_T_R  STR_LEG_M_A  STR_LEG_M_R  STR_DISTANCE_T_A  \
# 1978      0.65645     0.863555      0.65645     0.863555          0.428716
#
# ...

# %%
df_peleas = pd.read_csv(r"C:\Users\andre\OneDrive - Universidad Complutense de Madrid (UCM)\Escritorio\UNIVERSIDAD\2º\2º Cuatrimestre\PD1\c2425-R4\data\df_limpio.csv")
df_peleas[(df_peleas["Peleador_A"]=="Ilia Topuria") | (df_peleas["Peleador_B"]=="Ilia Topuria")]
# Out:
#       Unnamed: 0  index             Peleador_A     Peleador_B        DATE  \
# 5623        5623   4735          Youssef Zalal   Ilia Topuria  2020-10-10
# 5712        5712   4653           Ilia Topuria  Damon Jackson  2020-12-05
# 6000        6000   4362              Ryan Hall   Ilia Topuria  2021-07-10
# 6354        6354   4011            Jai Herbert   Ilia Topuria  2022-03-19
# 6737        6737   3622         Bryce Mitchell   Ilia Topuria  2022-12-10
# 7002        7002   3350            Josh Emmett   Ilia Topuria  2023-06-24
# 7327        7327   3023  Alexander Volkanovski   Ilia Topuria  2024-02-17
# 7705        7705   2644           Ilia Topuria   Max Holloway  2024-11-02
#
#            CATEGORY  WINNER                METHOD  TIME  ROUND  KD_A  KD_B  \
# 5623  FEATHERWEIGHT       1  Decision - Unanimous   300      3     0     0
# 5712  FEATHERWEIGHT       0                KO/TKO   158      1     1     0
# 6000  FEATHERWEIGHT       1                KO/TKO   287      1     0     0
# ...
